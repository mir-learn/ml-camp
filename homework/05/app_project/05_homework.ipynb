# %%
import pickle

input_file = 'pipeline_v1.bin'
with open(input_file, 'rb') as f_in: # very important to use 'rb' here, it means read-binary
    dict_vectorizer, model = pickle.load(f_in)

# %%
dict_vectorizer, model
# Out:
# (DictVectorizer(), LogisticRegression(solver='liblinear'))

# %%
input = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}

# %%
 dict_vectorizer.transform([input])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dict_vectorizer.transform([input])
#
# File ~/anaconda3/envs/ml-zoomcamp/lib/python3.13/site-packages/sklearn/utils/_set_output.py:316, in wrapped(self, X, *args, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/anaconda3/envs/ml-zoomcamp/lib/python3.13/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:383, in DictVectorizer.transform(self, X)
#     366 """Transform feature->value dicts to array or sparse matrix.
#     367
#     368 Named features not encountered during fit or fit_transform will be
#    (...)    380     Feature vectors; always 2-d.
#     381 """
#     382 check_is_fitted(self, ["feature_names_", "vocabulary_"])
# --> 383 return self._transform(X, fitting=False)
#
# File ~/anaconda3/envs/ml-zoomcamp/lib/python3.13/site-packages/sklearn/feature_extraction/_dict_vectorizer.py:230, in DictVectorizer._transform(self, X, fitting)
#     227 # collect all the possible feature names and build sparse matrix at
#     228 # same time
#     229 for x in X:
# --> 230     for f, v in x.items():
#     231         if isinstance(v, str):
#     232             feature_name = "%s%s%s" % (f, self.separator, v)
#
# AttributeError: 'function' object has no attribute 'items'
